# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os
import re

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm

import warnings
warnings.filterwarnings(action='ignore')

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ## Hyperparameter Setting

# %%
CFG = {
    'X_RANGE':3, # 예측하려는 시점을 X_RANGE 만큼의 이전 일자의 데이터로부터 예측 및 학습
    'EPOCHS':50,
    'LEARNING_RATE':1e-2,
    'BATCH_SIZE':128,
    'SEED':41
}

# %% [markdown]
# ## Fixed RandomSeed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ## Data Load

# %%
train_df = pd.read_csv('./train.csv')

# %%
train_df.head()
# Out:
#          일시    광진구   동대문구    성동구    중랑구
# 0  20180101  0.592  0.368  0.580  0.162
# 1  20180102  0.840  0.614  1.034  0.260
# 2  20180103  0.828  0.576  0.952  0.288
# 3  20180104  0.792  0.542  0.914  0.292
# 4  20180105  0.818  0.602  0.994  0.308

# %% [markdown]
# ## Data Visualization

# %%
def get_view_df(df, target):
    viewd = df[['일시', target]]
    viewd = viewd.reset_index(drop=True)
    viewd = viewd.reset_index()
    print(target)
    sns.set(rc = {'figure.figsize':(30,8)})
    sns.lineplot(x='index', y=target, data=viewd)
    plt.show()

# %%
get_view_df(train_df, '광진구')
get_view_df(train_df, '동대문구')
get_view_df(train_df, '성동구')
get_view_df(train_df, '중랑구')
# Out:
# 광진구
# 동대문구
# 성동구
# 중랑구

# %% [markdown]
# ## Train / Validation Split

# %%
val_df = train_df.iloc[1096-CFG['X_RANGE']:].reset_index().drop(columns='index') # 20210101 ~ 20211231
# 위의 1096-CFG['X_RANGE']의 이유는 20210101을 예측하기 위해서는 이전 X_RANGE만큼의 일수가 필요하므로
train_df = train_df.iloc[:1096].reset_index().drop(columns='index') # 20180101 ~ 20201231

# %% [markdown]
# ## Data Pre-processing

# %%
def get_x_y_data(df, infer=False):
    # x_range : x일전까지의 데이터를 통해 예측
    x_data = []
    y_data = []
    for i in tqdm(range(CFG['X_RANGE'], len(df))):
        x_data.append(np.array(df.loc[i-CFG['X_RANGE']:i-1, ['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]).astype(float))
        y_data.append(np.array(df.loc[i, ['광진구', '동대문구', '성동구', '중랑구']]).astype(float))
    if infer:
        return x_data
    else:
        return x_data, y_data

# %%
def make_ymd_feature(df):
    df['일시'] = df['일시'].astype(str)
    df['년'] = df['일시'].str[:4].astype(int)/1000.
    df['월'] = df['일시'].str[4:6].astype(int)/12.
    df['일'] = df['일시'].str[6:8].astype(int)/31.
    df = df[['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]
    return df

# %%
train_df = make_ymd_feature(train_df)
val_df = make_ymd_feature(val_df)

# %%
train_x, train_y = get_x_y_data(train_df)
# Out:
#   0%|          | 0/1093 [00:00<?, ?it/s]

# %%
val_x, val_y = get_x_y_data(val_df)
# Out:
#   0%|          | 0/365 [00:00<?, ?it/s]

# %% [markdown]
# ## CustomDataset

# %%
class CustomDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __getitem__(self, index):
        if self.Y is not None:
            return torch.Tensor(self.X[index]), torch.Tensor(self.Y[index])
        else:
            return torch.Tensor(self.X[index])

    def __len__(self):
        return len(self.X)

# %%
train_dataset = CustomDataset(train_x, train_y)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True, num_workers=0)

val_dataset = CustomDataset(val_x, val_y)
val_loader = DataLoader(val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %% [markdown]
# ## Define Model

# %%
class BaseModel(nn.Module):
    def __init__(self):
        super(BaseModel, self).__init__()
        self.lstm = nn.LSTM(input_size=7, hidden_size=256, num_layers=4, batch_first=True)
        
        self.multioutput_reg = nn.Sequential(
            nn.Linear(in_features=256, out_features=128), 
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Linear(in_features=128, out_features=4),
        )
        
    def forward(self, x):
        hidden, _ = self.lstm(x)
        output = self.multioutput_reg(hidden[:,-1,:])
        return output

# %% [markdown]
# ## Train

# %%
def train(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)
    criterion = nn.L1Loss().to(device)
    
    best_loss = 9999999
    best_model = None
    
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for X, Y in iter(train_loader):
            X = X.to(device)
            Y = Y.to(device)
            
            optimizer.zero_grad()
            
            output = model(X)
            loss = criterion(output, Y)
            
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
        
        _train_loss = np.mean(train_loss)
        
        val_mae = validation(model, val_loader, criterion, device)
        print(f'Epoch : [{epoch}] Train Loss : [{_train_loss:.5f}] Val MAE : [{val_mae:.5f}]')
        
        if scheduler is not None:
            scheduler.step(val_mae)
            
        if best_loss > val_mae:
            best_loss = val_mae
            best_model = model 
    return best_model

# %%
def validation(model, val_loader, criterion, device):
    model.eval()
    val_loss = []
    with torch.no_grad():
        for X, Y in iter(val_loader):
            X = X.to(device)
            Y = Y.to(device)
            
            output = model(X)
            
            loss = criterion(output, Y)
            
            val_loss.append(loss.item())
    
    _val_loss = np.mean(val_loss)
    return _val_loss

# %% [markdown]
# ## Run!!

# %%
model = BaseModel()

# %%
optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=4,threshold_mode='abs',min_lr=1e-8, verbose=True)
best_model = train(model, optimizer, train_loader, val_loader, scheduler, device) # 2018.01.01 ~ 2020.12.31 까지 데이터로 학습
# Out:
# Epoch : [1] Train Loss : [2.70971] Val MAE : [5.91163]
# Epoch : [2] Train Loss : [1.33343] Val MAE : [2.14204]
# Epoch : [3] Train Loss : [1.23706] Val MAE : [2.01967]
# Epoch : [4] Train Loss : [1.18055] Val MAE : [1.94538]
# Epoch : [5] Train Loss : [1.25365] Val MAE : [1.94278]
# Epoch : [6] Train Loss : [1.08598] Val MAE : [1.93895]
# Epoch     6: reducing learning rate of group 0 to 5.0000e-03.
# Epoch : [7] Train Loss : [1.00799] Val MAE : [1.86150]
# Epoch : [8] Train Loss : [0.96725] Val MAE : [1.92178]
# Epoch : [9] Train Loss : [1.05011] Val MAE : [1.81094]
# Epoch : [10] Train Loss : [1.01224] Val MAE : [1.79321]
# Epoch : [11] Train Loss : [1.01895] Val MAE : [1.93350]
# Epoch    11: reducing learning rate of group 0 to 2.5000e-03.
# Epoch : [12] Train Loss : [1.00497] Val MAE : [1.68625]
# Epoch : [13] Train Loss : [0.96825] Val MAE : [1.69540]
# Epoch : [14] Train Loss : [0.90888] Val MAE : [1.60870]
# Epoch : [15] Train Loss : [0.91093] Val MAE : [1.61905]
# Epoch : [16] Train Loss : [0.96991] Val MAE : [1.60543]
# Epoch    16: reducing learning rate of group 0 to 1.2500e-03.
# Epoch : [17] Train Loss : [0.89455] Val MAE : [1.60983]
# Epoch : [18] Train Loss : [0.97806] Val MAE : [1.61114]
# Epoch : [19] Train Loss : [0.86682] Val MAE : [1.64782]
# Epoch : [20] Train Loss : [0.94159] Val MAE : [1.66118]
# Epoch : [21] Train Loss : [0.84275] Val MAE : [1.56498]
# Epoch    21: reducing learning rate of group 0 to 6.2500e-04.
# Epoch : [22] Train Loss : [0.85073] Val MAE : [1.59971]
# Epoch : [23] Train Loss : [0.84021] Val MAE : [1.59664]
# Epoch : [24] Train Loss : [0.82334] Val MAE : [1.56933]
# Epoch : [25] Train Loss : [0.85389] Val MAE : [1.58558]
# Epoch : [26] Train Loss : [0.86902] Val MAE : [1.56612]
# Epoch    26: reducing learning rate of group 0 to 3.1250e-04.
# Epoch : [27] Train Loss : [0.86115] Val MAE : [1.57256]
# Epoch : [28] Train Loss : [0.84128] Val MAE : [1.57026]
# Epoch : [29] Train Loss : [0.85841] Val MAE : [1.57576]
# Epoch : [30] Train Loss : [0.87704] Val MAE : [1.58502]
# Epoch : [31] Train Loss : [0.91473] Val MAE : [1.59062]
# Epoch    31: reducing learning rate of group 0 to 1.5625e-04.
# Epoch : [32] Train Loss : [0.85009] Val MAE : [1.58619]
# Epoch : [33] Train Loss : [0.86358] Val MAE : [1.58676]
# Epoch : [34] Train Loss : [0.81954] Val MAE : [1.57848]
# Epoch : [35] Train Loss : [0.81233] Val MAE : [1.57112]
# Epoch : [36] Train Loss : [0.82411] Val MAE : [1.56646]
# Epoch    36: reducing learning rate of group 0 to 7.8125e-05.
# Epoch : [37] Train Loss : [0.83892] Val MAE : [1.56738]
# Epoch : [38] Train Loss : [0.88041] Val MAE : [1.58594]
# Epoch : [39] Train Loss : [0.84807] Val MAE : [1.57191]
# Epoch : [40] Train Loss : [0.80937] Val MAE : [1.57217]
# Epoch : [41] Train Loss : [0.83077] Val MAE : [1.56483]
# Epoch    41: reducing learning rate of group 0 to 3.9063e-05.
# Epoch : [42] Train Loss : [0.83300] Val MAE : [1.57580]
# Epoch : [43] Train Loss : [0.84770] Val MAE : [1.57058]
# Epoch : [44] Train Loss : [0.83892] Val MAE : [1.57014]
# Epoch : [45] Train Loss : [0.84579] Val MAE : [1.56666]
# Epoch : [46] Train Loss : [0.83076] Val MAE : [1.57459]
# Epoch    46: reducing learning rate of group 0 to 1.9531e-05.
# Epoch : [47] Train Loss : [0.81903] Val MAE : [1.57363]
# Epoch : [48] Train Loss : [0.83021] Val MAE : [1.57086]
# Epoch : [49] Train Loss : [0.83005] Val MAE : [1.56993]
# Epoch : [50] Train Loss : [0.81498] Val MAE : [1.56782]

# %% [markdown]
# ## Inference

# %%
test_df = pd.read_csv('./sample_submission.csv')
test_df = make_ymd_feature(test_df)
test_df = pd.concat([val_df[CFG['X_RANGE']*(-1):], test_df]).reset_index().drop(columns='index')

# %%
test_df.head()
# Out:
#          년         월         일    광진구   동대문구   성동구    중랑구
# 0    2.021  1.000000  0.935484  4.490  3.524  3.66  2.524
# 1    2.021  1.000000  0.967742  4.444  3.574  3.53  2.506
# 2    2.021  1.000000  1.000000  3.616  3.210  2.62  2.146
# 3    2.022  0.083333  0.032258  0.000  0.000  0.00  0.000
# 4    2.022  0.083333  0.064516  0.000  0.000  0.00  0.000
# ..     ...       ...       ...    ...    ...   ...    ...
# 332  2.022  0.916667  0.838710  0.000  0.000  0.00  0.000
# 333  2.022  0.916667  0.870968  0.000  0.000  0.00  0.000
# 334  2.022  0.916667  0.903226  0.000  0.000  0.00  0.000
# 335  2.022  0.916667  0.935484  0.000  0.000  0.00  0.000
# 336  2.022  0.916667  0.967742  0.000  0.000  0.00  0.000
#
# [337 rows x 7 columns]

# %%
def inference(model, df, device):
    model.to(device)
    model.eval()
    for i in tqdm(range(CFG['X_RANGE'], len(df))):
        X = torch.Tensor(np.array(df.loc[i-CFG['X_RANGE']:i-1, ['년', '월', '일', '광진구', '동대문구', '성동구', '중랑구']]).astype(float)).unsqueeze(0)
        X = X.to(device)
        with torch.no_grad():
            model_pred = model(X)[0]
        
        model_pred = model_pred.cpu().numpy()
        df.loc[i, ['광진구', '동대문구', '성동구', '중랑구']] = model_pred
    return df.loc[CFG['X_RANGE']:, ['광진구', '동대문구', '성동구', '중랑구']].reset_index().drop(columns=['index'])

# %%
preds = inference(best_model, test_df, device)
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]

# %% [markdown]
# ## Submission

# %%
submit = pd.read_csv('./sample_submission.csv')
submit.head()
# Out:
#          일시  광진구  동대문구  성동구  중랑구
# 0  20220101    0     0    0    0
# 1  20220102    0     0    0    0
# 2  20220103    0     0    0    0
# 3  20220104    0     0    0    0
# 4  20220105    0     0    0    0

# %%
submit['광진구'] = preds['광진구'].round(3)
submit['동대문구'] = preds['동대문구'].round(3)
submit['성동구'] = preds['성동구'].round(3)
submit['중랑구'] = preds['중랑구'].round(3)

# %%
submit.to_csv('./submit.csv', index=False)
